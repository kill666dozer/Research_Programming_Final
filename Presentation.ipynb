# %% [markdown]
# # gTrack Analyzer

# %% [markdown]
# In order to study cellular dynamics on the molecular level, we use localizaiton techniques such as PALM to observe the position and movement of tagged molecules.

# %%
import csvReadIn
import plottingFunctions
import trackManipulations
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
coordAmp = csvReadIn.make_coordAmp_dataframe(csvReadIn.load_csv())

# %%
coordAmp.loc[:9, 'xPos 1'::1]
# Out:
#      xPos 1   yPos 1  zPos 1  amplitude 1  xUncertainty 1  yUncertainty 1  \
# 0  248.1500  132.050       0     0.008190        0.097350        0.097366
# 1  237.6100   68.525       0     0.012734        0.066805        0.066798
# 2  183.7200   45.710       0     0.002764        0.245480        0.245470
# 3    6.7090   65.816       0     0.018873        0.093894        0.093902
# 4   66.2600  173.210       0     0.006262        0.224750        0.224790
# 5    5.8707  177.960       0     0.005373        0.297860        0.297890
# 6  152.3700  237.430       0     0.004974        0.142060        0.142050
# 7   63.7500  167.890       0     0.007840        0.179520        0.179580
# 8   47.5320  152.840       0     0.009273        0.144650        0.144750
# 9   66.3990  196.200       0     0.005450        0.258140        0.258270
#
#    zUncertainty 1  ampUncertainty 1    xPos 2   yPos 2         ...          \
# 0               0          0.000593  247.4000  132.140         ...
# 1               0          0.000633  237.5500   68.587         ...
# 2               0          0.000505  183.3100   45.595         ...
# 3               0          0.001277    6.8919   65.771         ...
# 4               0          0.000998   65.2170  173.670         ...
# 5               0          0.001148    5.5777  177.160         ...
# 6               0          0.000526  152.8800  237.770         ...
# 7               0          0.000998   63.4650  168.330         ...
# 8               0          0.000957   46.2790  152.800         ...
# 9               0          0.000983   64.3690  197.130         ...
#
#    zUncertainty 398  ampUncertainty 398  xPos 399  yPos 399  zPos 399  \
# 0               NaN                 NaN       NaN       NaN       NaN
# 1               NaN                 NaN       NaN       NaN       NaN
# 2                 0            0.000549       184    45.637         0
# 3               NaN                 NaN       NaN       NaN       NaN
# 4               NaN                 NaN       NaN       NaN       NaN
# 5               NaN                 NaN       NaN       NaN       NaN
# 6               NaN                 NaN       NaN       NaN       NaN
# 7               NaN                 NaN       NaN       NaN       NaN
# 8               NaN                 NaN       NaN       NaN       NaN
# 9               NaN                 NaN       NaN       NaN       NaN
#
#    amplitude 399  xUncertainty 399  yUncertainty 399  zUncertainty 399  \
# 0            NaN               NaN               NaN               NaN
# 1            NaN               NaN               NaN               NaN
# 2       0.003465           0.24881           0.24864                 0
# 3            NaN               NaN               NaN               NaN
# 4            NaN               NaN               NaN               NaN
# 5            NaN               NaN               NaN               NaN
# 6            NaN               NaN               NaN               NaN
# 7            NaN               NaN               NaN               NaN
# 8            NaN               NaN               NaN               NaN
# 9            NaN               NaN               NaN               NaN
#
#    ampUncertainty 399
# 0                 NaN
# 1                 NaN
# 2            0.000641
# 3                 NaN
# 4                 NaN
# 5                 NaN
# 6                 NaN
# 7                 NaN
# 8                 NaN
# 9                 NaN
#
# [10 rows x 3192 columns]

# %%
coordAmp.loc[20:29, 'xPos 1'::1]
# Out:
#     xPos 1  yPos 1  zPos 1  amplitude 1  xUncertainty 1  yUncertainty 1  \
# 20  38.187  214.30       0     0.022886        0.073538        0.073493
# 21  94.931  162.55       0     0.011504        0.126920        0.126800
# 22  77.577  210.83       0     0.003075        0.285070        0.285240
# 23  91.617  139.25       0     0.005181        0.264660        0.264750
# 24     NaN     NaN     NaN          NaN             NaN             NaN
# 25     NaN     NaN     NaN          NaN             NaN             NaN
# 26     NaN     NaN     NaN          NaN             NaN             NaN
# 27     NaN     NaN     NaN          NaN             NaN             NaN
# 28     NaN     NaN     NaN          NaN             NaN             NaN
# 29     NaN     NaN     NaN          NaN             NaN             NaN
#
#     zUncertainty 1  ampUncertainty 1   xPos 2   yPos 2         ...          \
# 20               0          0.001171   38.611  214.030         ...
# 21               0          0.001012   95.493  163.180         ...
# 22               0          0.000653   76.972  209.990         ...
# 23               0          0.000987   92.167  137.780         ...
# 24             NaN               NaN   97.175  148.480         ...
# 25             NaN               NaN   88.943  175.400         ...
# 26             NaN               NaN   39.254  167.410         ...
# 27             NaN               NaN   49.904  144.520         ...
# 28             NaN               NaN  102.010   21.285         ...
# 29             NaN               NaN      NaN      NaN         ...
#
#     zUncertainty 398  ampUncertainty 398  xPos 399  yPos 399  zPos 399  \
# 20               NaN                 NaN       NaN       NaN       NaN
# 21               NaN                 NaN       NaN       NaN       NaN
# 22               NaN                 NaN       NaN       NaN       NaN
# 23               NaN                 NaN       NaN       NaN       NaN
# 24               NaN                 NaN       NaN       NaN       NaN
# 25               NaN                 NaN       NaN       NaN       NaN
# 26               NaN                 NaN       NaN       NaN       NaN
# 27               NaN                 NaN       NaN       NaN       NaN
# 28               NaN                 NaN       NaN       NaN       NaN
# 29               NaN                 NaN       NaN       NaN       NaN
#
#     amplitude 399  xUncertainty 399  yUncertainty 399  zUncertainty 399  \
# 20            NaN               NaN               NaN               NaN
# 21            NaN               NaN               NaN               NaN
# 22            NaN               NaN               NaN               NaN
# 23            NaN               NaN               NaN               NaN
# 24            NaN               NaN               NaN               NaN
# 25            NaN               NaN               NaN               NaN
# 26            NaN               NaN               NaN               NaN
# 27            NaN               NaN               NaN               NaN
# 28            NaN               NaN               NaN               NaN
# 29            NaN               NaN               NaN               NaN
#
#     ampUncertainty 399
# 20                 NaN
# 21                 NaN
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
#
# [10 rows x 3192 columns]

# %% [markdown]
# Important notes:
#
# Each row represents a single track. Every 8 columns represents data on that track from a single frame. Since tracks only last for a handful of frames, most of the cells in this dataframe are empty.
#
# You will also notice that precision is proportional to amplitude.

# %%
plt.clf()
plt.scatter(coordAmp['amplitude 1'], coordAmp['xUncertainty 1'])
plt.show()
# Out:
# /Users/scottbreitenstein/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Therefore, we can scrub the data of dim, low-precision data.

# %% [markdown]
# Since we have the location of every point in our Pandas dataframe, we'll plot them all:

# %%
plottingFunctions.plot_points(coordAmp)
# Out:
# /Users/scottbreitenstein/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# We can also plot individual tracks by accessing certain rows. We could plot, say track 60:

# %%
plottingFunctions.plot_track(coordAmp,60)
# Out:
# /Users/scottbreitenstein/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# Or we can plot all of them at once.

# %%
plt.clf()
plottingFunctions.plot_all_tracks(coordAmp)

# %% [markdown]
# In order to visualize the higher order patterns of molecular dynamics, I found the average vectors of motion for each track.

# %%
plt.clf()
plottingFunctions.plot_mean_vectors(coordAmp)
# Out:
# /Users/scottbreitenstein/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# By converting these vectors into polar coordinates, I could determine their direction and use that as the color map variable. This gives me an idea of where the molecules are headed.

# %%
plt.clf()
plottingFunctions.plot_vector_direction(coordAmp)
# Out:
# /Users/scottbreitenstein/anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# More interesting still is the density heatmap function, which creates a heatmap of particle density based on the average position of each particle.

# %%
plt.clf()
plottingFunctions.plot_density_heatmap(coordAmp)
